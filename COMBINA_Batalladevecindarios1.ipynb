# %% [markdown]
# <a href="https://colab.research.google.com/github/clarrabureg/testrepo/blob/main/COMBINA_Batalladevecindarios1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## PROGRAMA QUE COMBINA Y CALCULA DATA
## Trabajo final Batalla de vecindarios LIMA (parte1)
#  Tabla   
## 24-06-2022
## C.L.L.G

# %% [markdown]
# ---
# #### 1. CARGA LIBRERIAS
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib as plt
from datetime import date, time, datetime

# %% [markdown]
# ---
# #### 2. CARGA LOS ARCHIVOS DE DATOS
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# CONSIDERAR CARGAR EL ARCHIVO EN JUPYTER O COLAB Y CAMBIAR LA RUTA SI NO LO CORREN CON LOCAL COMO EN ESTE CASO
# SI EL ARCHIVO ES EN CSV USA ESTA LINEA
df_original = pd.read_csv("/content/drive/MyDrive/labatalla/newubigeo.csv", sep = ",")
df_original1 = pd.read_csv("/content/drive/MyDrive/labatalla/newgeo.csv", sep = ",")
# SI EL ARCHIVO ES EN EXCEL USA ESTA LINEA 
#df_original = pd.read_excel("/content/drive/MyDrive/labatalla/GeoPeru-peru_distritos.xlsx")
df_copia = df_original
df_copia1= df_original1

# %% [markdown]
# ---
# #### 3. INICIO DE PROCESO DE REVISION Y COMPRENSION DE LA ESTRUCTURA DE LA TABLA Y DATOS ALMACENADOS EN ELLA
# ---

# %%
# CUENTA EL NRO TOTAL DE FILAS, COLUMNAS Y CELDAS DEL ARCHIVO ORIGINAL Y LOS ALMACENA EN UNA VARIABLE
Tot_filas=len(df_original)
Tot_columnas=len(df_original.columns)
Tot_celdas=df_original.size
print("El número total de filas del archivo es    -->:",len(df_original))
print("El número total de columnas del archivo es -->:",len(df_original.columns))
print("El número total de celdas   del archivo es -->:",df_original.size)
# Out:
# El número total de filas del archivo es    -->: 43
# El número total de columnas del archivo es -->: 10
# El número total de celdas   del archivo es -->: 430

# %%
# CUENTA EL NRO TOTAL DE FILAS, COLUMNAS Y CELDAS DEL ARCHIVO ORIGINAL1 Y LOS ALMACENA EN UNA VARIABLE
Tot_filas=len(df_original1)
Tot_columnas=len(df_original1.columns)
Tot_celdas=df_original1.size
print("El número total de filas del archivo es    -->:",len(df_original1))
print("El número total de columnas del archivo es -->:",len(df_original1.columns))
print("El número total de celdas   del archivo es -->:",df_original1.size)
# Out:
# El número total de filas del archivo es    -->: 43
# El número total de columnas del archivo es -->: 11
# El número total de celdas   del archivo es -->: 473

# %%
## INICIA REVISION DEL ARCHIVO - PROCESO DE COMPRENSION DE LA ESTRUCTRA DE DATOS Y CONTENIDO DEL ARCHIVO ORIGINAL
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     43 non-null     int64
#  1   id_ubigeo      43 non-null     int64
#  2   departamento   43 non-null     object
#  3   provincia      43 non-null     object
#  4   distrito       43 non-null     object
#  5   region         43 non-null     object
#  6   altitud        43 non-null     float64
#  7   latitud        43 non-null     float64
#  8   longitud       43 non-null     float64
#  9   porcentaje_AB  43 non-null     float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 3.5+ KB

# %%
df_original1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    43 non-null     int64
#  1   Unnamed: 0.1  43 non-null     int64
#  2   total_pers    43 non-null     int64
#  3   cod_dpto      43 non-null     int64
#  4   departamento  43 non-null     object
#  5   cod_prov      43 non-null     int64
#  6   provincia     43 non-null     object
#  7   cod_dist      43 non-null     int64
#  8   distrito      43 non-null     object
#  9   num_hog       43 non-null     int64
#  10  pob_total     43 non-null     int64
# dtypes: int64(8), object(3)
# memory usage: 3.8+ KB

# %%
## renombra columnas
df_copia1.rename(columns = {'nom_dpto':'departamento'}, inplace = True)
df_copia1.rename(columns = {'nom_prov':'provincia'}, inplace = True)
df_copia1.rename(columns = {'nom_dist':'distrito'}, inplace = True)
df_copia1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  total_pers  cod_dpto departamento  cod_prov  \
# 0           0           827         985        15         LIMA      1501
# 1           1           841       33893        15         LIMA      1501
# 2           2           842       88381        15         LIMA      1501
# 3           3           843      109003        15         LIMA      1501
# 4           4           848       14486        15         LIMA      1501
#
#   provincia  cod_dist             distrito  num_hog  pob_total
# 0      LIMA    150138  SANTA MARIA DEL MAR      300        999
# 1      LIMA    150109          CIENEGUILLA     9623      34684
# 2      LIMA    150119                LURIN    23865      89195
# 3      LIMA    150123           PACHACAMAC    30335     110071
# 4      LIMA    150124             PUCUSANA     4377      14891

# %%
## genera nueva base uniendo datos de ubigeo
df_new= pd.merge(df_copia,df_copia1,on="distrito",how="right")
df_new.columns
# Out:
# Index(['Unnamed: 0_x', 'id_ubigeo', 'departamento_x', 'provincia_x',
#        'distrito', 'region', 'altitud', 'latitud', 'longitud', 'porcentaje_AB',
#        'Unnamed: 0_y', 'Unnamed: 0.1', 'total_pers', 'cod_dpto',
#        'departamento_y', 'cod_prov', 'provincia_y', 'cod_dist', 'num_hog',
#        'pob_total'],
#       dtype='object')

# %%
df_new = df_new.drop(['Unnamed: 0_x', 'Unnamed: 0_y', 'Unnamed: 0.1', 'departamento_y', 'provincia_y'], axis=1)
df_new.head(50)
# Out:
#     id_ubigeo departamento_x provincia_x                 distrito  \
# 0        1318           LIMA        LIMA      SANTA MARIA DEL MAR
# 1        1289           LIMA        LIMA              CIENEGUILLA
# 2        1299           LIMA        LIMA                    LURIN
# 3        1303           LIMA        LIMA               PACHACAMAC
# 4        1304           LIMA        LIMA                 PUCUSANA
# 5        1286           LIMA        LIMA               CARABAYLLO
# 6        1306           LIMA        LIMA            PUNTA HERMOSA
# 7        1307           LIMA        LIMA              PUNTA NEGRA
# 8        1309           LIMA        LIMA              SAN BARTOLO
# 9        1305           LIMA        LIMA            PUENTE PIEDRA
# 10       1313           LIMA        LIMA   SAN JUAN DE MIRAFLORES
# 11       1320           LIMA        LIMA        SANTIAGO DE SURCO
# 12       1322           LIMA        LIMA        VILLA EL SALVADOR
# ...

# %%
## REEMPLAZA VALOR DE % POBLACION_AB
df_new.loc[(df_new['distrito'] =="MIRAFLORES"), "porcentaje_AB"]=78.9
df_new.loc[(df_new['distrito'] =="SAN ISIDRO"), "porcentaje_AB"]=78.9
df_new.loc[(df_new['distrito'] =="SAN BORJA"), "porcentaje_AB"]=78.9
df_new.loc[(df_new['distrito'] =="SANTIAGO DE SURCO"), "porcentaje_AB"]=78.9
df_new.loc[(df_new['distrito'] =="LA MOLINA"), "porcentaje_AB"]=78.9
df_new.loc[(df_new['distrito'] =="JESUS MARIA"), "porcentaje_AB"]=70.2
df_new.loc[(df_new['distrito'] =="LINCE"), "porcentaje_AB"]=70.2
df_new.loc[(df_new['distrito'] =="PUEBLO LIBRE"), "porcentaje_AB"]=70.2
df_new.loc[(df_new['distrito'] =="MAGDALENA DEL MAR"), "porcentaje_AB"]=70.2
df_new.loc[(df_new['distrito'] =="SAN MIGUEL"), "porcentaje_AB"]=70.2
df_new.loc[(df_new['distrito'] =="SURQUILLO"), "porcentaje_AB"]=24.8
df_new.loc[(df_new['distrito'] =="BARRANCO"), "porcentaje_AB"]=24.8
df_new.loc[(df_new['distrito'] =="CHORRILLOS"), "porcentaje_AB"]=24.8
df_new.loc[(df_new['distrito'] =="SAN JUAN DE MIRAFLORES"), "porcentaje_AB"]=24.8
df_new.loc[(df_new['distrito'] =="INDEPENDENCIA"), "porcentaje_AB"]=23.6
df_new.loc[(df_new['distrito'] =="LOS OLIVOS"), "porcentaje_AB"]=23.6
df_new.loc[(df_new['distrito'] =="SAN MARTIN DE PORRES"), "porcentaje_AB"]=23.6
df_new.loc[(df_new['distrito'] =="ATE"), "porcentaje_AB"]=13.2
df_new.loc[(df_new['distrito'] =="CHACLACAYO"), "porcentaje_AB"]=13.2
df_new.loc[(df_new['distrito'] =="LURIGANCHO"), "porcentaje_AB"]=13.2
df_new.loc[(df_new['distrito'] =="SANTA ANITA"), "porcentaje_AB"]=13.2
df_new.loc[(df_new['distrito'] =="SAN LUIS"), "porcentaje_AB"]=13.2
df_new.loc[(df_new['distrito'] =="EL AGUSTINO"), "porcentaje_AB"]=13.2
df_new.loc[(df_new['distrito'] =="PUENTE PIEDRA"), "porcentaje_AB"]=13.1
df_new.loc[(df_new['distrito'] =="COMAS"), "porcentaje_AB"]=13.1
df_new.loc[(df_new['distrito'] =="CARABAYLLO"), "porcentaje_AB"]=13.1
df_new.loc[(df_new['distrito'] =="SAN JUAN DE LURIGANCHO"), "porcentaje_AB"]=13.1
df_new.loc[(df_new['distrito'] =="LIMA"), "porcentaje_AB"]=23.7
df_new.loc[(df_new['distrito'] =="RIMAC"), "porcentaje_AB"]=23.7
df_new.loc[(df_new['distrito'] =="BREÑA"), "porcentaje_AB"]=23.7
df_new.loc[(df_new['distrito'] =="LA VICTORIA"), "porcentaje_AB"]=23.7
df_new.loc[(df_new['distrito'] =="VILLA EL SALVADOR"), "porcentaje_AB"]=10.7
df_new.loc[(df_new['distrito'] =="VILLA MARIA DEL TRIUNFO"), "porcentaje_AB"]=10.7
df_new.loc[(df_new['distrito'] =="LURIN"), "porcentaje_AB"]=10.7
df_new.loc[(df_new['distrito'] =="PACHACAMAC"), "porcentaje_AB"]=10.7
df_new.loc[(df_new['distrito'] =="SANTA MARIA DEL MAR"), "porcentaje_AB"]=12
df_new.loc[(df_new['distrito'] =="CIENEGUILLA"), "porcentaje_AB"]=12
df_new.loc[(df_new['distrito'] =="PUCUSANA"), "porcentaje_AB"]=12
df_new.loc[(df_new['distrito'] =="PUNTA HERMOSA"), "porcentaje_AB"]=12
df_new.loc[(df_new['distrito'] =="PUNTA NEGRA"), "porcentaje_AB"]=12
df_new.loc[(df_new['distrito'] =="SAN BARTOLO"), "porcentaje_AB"]=12
df_new.loc[(df_new['distrito'] =="SANTA ROSA"), "porcentaje_AB"]=12
df_new.loc[(df_new['distrito'] =="ANCON"), "porcentaje_AB"]=12

# %%
df_new.head(50)
# Out:
#     id_ubigeo departamento_x provincia_x                 distrito  \
# 0        1318           LIMA        LIMA      SANTA MARIA DEL MAR
# 1        1289           LIMA        LIMA              CIENEGUILLA
# 2        1299           LIMA        LIMA                    LURIN
# 3        1303           LIMA        LIMA               PACHACAMAC
# 4        1304           LIMA        LIMA                 PUCUSANA
# 5        1286           LIMA        LIMA               CARABAYLLO
# 6        1306           LIMA        LIMA            PUNTA HERMOSA
# 7        1307           LIMA        LIMA              PUNTA NEGRA
# 8        1309           LIMA        LIMA              SAN BARTOLO
# 9        1305           LIMA        LIMA            PUENTE PIEDRA
# 10       1313           LIMA        LIMA   SAN JUAN DE MIRAFLORES
# 11       1320           LIMA        LIMA        SANTIAGO DE SURCO
# 12       1322           LIMA        LIMA        VILLA EL SALVADOR
# ...

# %%
df_new.to_csv("/content/drive/MyDrive/labatalla/newtabla.csv")

# %% [markdown]
# ---------------------------------------------------------------
# **Fin de programa**
#
# ---------------------------------------------------------------

# %% [raw]
# ---
# #### 4. FIN DE PROCESO DE LIMPIEZA DE TABLA - GENERACION DE NUEVO ARCHIVO TRANSFORMADO
# ---

# %%
## GRABA LA TABLA LUEGO DEL PROCESO DE LIMPIEZA - SE USA EL IDENTIFICADOR NEW PARA INDICAR QUE ES LA TABLA LIMPIA
df_copia.to_csv('C:/Users/c_lar/Documents/DATASCIENCE2/BASESTRANSFORMADAS/3_NEW_TB_POSITIVOS_COVID.csv')
